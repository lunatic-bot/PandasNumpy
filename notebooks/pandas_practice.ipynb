# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv("titanic.csv", index_col=['PassengerId'])
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
import seaborn as sns
sns.boxplot(x="Pclass", y="Fare", data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
# df = pd.read_csv("titanic.csv", usecols = [0, 1, 2, 5, 6, 7, 9])
# df

titanic.shape
# Out:
# (891, 11)

# %%
## Always position based - excludes last position when slicing

df = titanic.iloc[1:5] ## gets roews from 1st to 5th index
# df = titanic.iloc[:, 4] ## all rows with 4th column
# df = titanic.iloc[1:,] ## all rows except first, all columns
# # df = titanic.iloc[:5,] ## top 5 rows
df = titanic.iloc[1:5, 2:6] ## row index 1 to 5(total 4 rows), columns from 2-6(total 4)
# df = titanic.iloc[['Age']] # fails, needs an index
df = titanic.iloc[[1,3], [1, 2, 3]]  ## index 1 and 3 and column 1, 2, 3(index)
df = titanic.iloc[1:3, [1, 2, 3]]  ## index 1 and 2 and column 1, 2, 3(index)
df
# Out:
#              Pclass                                               Name     Sex
# PassengerId
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                 3                             Heikkinen, Miss. Laina  female

# %%
## Boolean -

# %%
## Always label based (whatever the label is) - slices are inclusive

df = titanic.loc[1:5] ## gets roews from 1st to 5th label
# df = titanic.loc[:, 4] ## does not work, loc in label based
df = titanic.loc[1:,] ## all rows from '1' label, all columns
df = titanic.loc[:5,] ## top 5 rows - upto label 5
# df

# %%
df = titanic.loc[[1, 3, 4]]  # gets 1st, 3rd, 4th row
df = titanic.loc[1, "Name"]  # name of the passenger for label index 1 (two arguments only)
# df = titanic.loc[1, "Name", "Age"]  # FAILS - .loc[row, col] takes two arguments only:
df = titanic.loc[1, ["Name", "Age"]] # name, age of the passenger for label index 1
df = titanic.loc[:, ["Name", "Age"]] # all rows, these columns
df = titanic.loc[1:5, ["Name", "Age"]] # 1-5 rows(labels), these columns
df = titanic.loc[[1, 5], ["Name", "Age"]] # Name age for index 1 and 5(label)
df = titanic.loc[[1, 5], "Name":"Age"] # Name, Sex, age for index 1 and 5(label)
# df

# %%
## boolean - 
df = titanic.loc[titanic["Age"] > 30, "Name"]  ## name with age > 30
df = titanic.loc[titanic["Age"] > 30, ["Name", "Age"]]  ## name, Age with age > 30
df
# Out:
#                                                           Name   Age
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 7                                      McCarthy, Mr. Timothy J  54.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...                                                        ...   ...
# 874                                Vander Cruyssen, Mr. Victor  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 882                                         Markun, Mr. Johann  33.0
# 886                       Rice, Mrs. William (Margaret Norton)  39.0
# 891                                        Dooley, Mr. Patrick  32.0
#
# [305 rows x 2 columns]

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "Doggie", "Eli", "Facy", "Gautham", "Hek", "Issac", "Jacob"],
    "Age": [25, 30, 35, 20, 21, 19, 29, 18, 15, 40],
    "City": ["Delhi", "Mumbai", "Bangalore", "Lucknow", "Trichy", "Mumbai", "Bangalore", "Delhi", "Chennai", "New York"]
}, index=["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"])

df
# Out:
#       Name  Age       City
# a    Alice   25      Delhi
# b      Bob   30     Mumbai
# c  Charlie   35  Bangalore
# d   Doggie   20    Lucknow
# e      Eli   21     Trichy
# f     Facy   19     Mumbai
# g  Gautham   29  Bangalore
# h      Hek   18      Delhi
# i    Issac   15    Chennai
# j    Jacob   40   New York

# %%
# df = df.iloc[[True, False, True, False, True, False, True, False, True, False], 1]
# df

# df.loc["a":"d"]  # rows with labels 'a' to 'd' (inclusive)
df.iloc[0:2] # 0-2 (2 exculsive)
# Out:
#     Name  Age    City
# a  Alice   25   Delhi
# b    Bob   30  Mumbai

# %%
# Select by label
# print(df.loc["a"])        # Row with index 'a'

# # Multiple labels
# print(df.loc[["a", "c"]]) # Rows 'a' and 'c'

# # Label slice (inclusive of 'c')
# print(df.loc["a":"c"])

# # Specific row + column
# print(df.loc["f", "City"])  # Mumbai

df.loc["c"]  ## all columns
# Out:
# Name      Charlie
# Age            35
# City    Bangalore
# Name: c, dtype: object

# %% [markdown]
# #### Filter in pandas

# %%
# axis=0 → rows, axis=1 → columns
# when selecting by labels (columns by name, pattern, etc.).
# Used mainly to filter rows/columns by labels (names, regex, lists).

df = titanic.filter(["Name", "Age", "Fare"])  ## Name, age, Fare
df = titanic.filter(like="me", axis=1)  ## column names like
df = titanic.filter(regex="^P",axis=1)
df
# Out:
#              Pclass  Parch
# PassengerId
# 1                 3      0
# 2                 1      0
# 3                 3      0
# 4                 1      0
# 5                 3      0
# ...             ...    ...
# 887               2      0
# 888               1      0
# 889               3      2
# 890               1      0
# 891               3      0
#
# [891 rows x 2 columns]

# %% [markdown]
# #### Query in pandas -

# %%
# when filtering rows by data values.
# Used to filter rows by conditions on column values.

df = titanic.query("Age > 25") ## all rows where age > 25
df = titanic.query("Sex == 'male'")  ## where sex is male
df = titanic.query("Age > 35 and Sex == 'male'")
df
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 14                  0       3     Andersson, Mr. Anders Johan  male  39.0
# 31                  0       1        Uruchurtu, Don. Manuel E  male  40.0
# 34                  0       2           Wheadon, Mr. Edward H  male  66.0
# 36                  0       1  Holverson, Mr. Alexander Oskar  male  42.0
# ...               ...     ...                             ...   ...   ...
# 846                 0       3             Abbing, Mr. Anthony  male  42.0
# 852                 0       3             Svensson, Mr. Johan  male  74.0
# 858                 1       1          Daly, Mr. Peter Denis   male  51.0
# 861                 0       3         Hansen, Mr. Claus Peter  male  41.0
# 874                 0       3     Vander Cruyssen, Mr. Victor  male  47.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### Super store dataset

# %%
import pandas as pd

store_df = pd.read_csv("Sample-Superstore.csv",  encoding="latin1")
store_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
store_df.shape
# Out:
# (9994, 21)

# %%
store_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# store_df.isna()

# %%
# store_df.describe

# %%
store_df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# print(store_df.groupby('Category')["Sales"].mean()) ## mean sales in categories
# print(store_df.groupby('Category')["Sales"].sum())  ## sum of sales in categories
# print(store_df.groupby('Category')["Quantity"].count()) ## count of order quantities
# print(store_df.groupby('Category')["Profit"].mean()) ## mean profit

# print(store_df.groupby('Category')["Sales"]) ## group object

# %%
grouped = store_df.groupby("Category").agg(
    {"Sales" : "sum", "Profit" : "mean", "Order ID":"count"}
    ).rename(
        columns={"Order ID" : "Order_Count"})
print(grouped)
# Out:
#                        Sales     Profit  Order_Count
# Category
# Furniture        741999.7953   8.699327         2121
# Office Supplies  719047.0320  20.327050         6026
# Technology       836154.0330  78.752002         1847

# %%
## calculate profit margin - 
# def profit_margin(X):
#     return (X['Profit'].sum()/X['Sales'].sum())*100


# result = store_df.groupby("Category").agg({"Sales" : "sum", "Profit" : "sum"}).assign(Profit_margin=lambda x: (x['Profit']/x['Sales'])*100)

# print(result)


result = store_df.groupby("Category").agg(
    Total_sales=("Sales", "sum"), 
    Total_profit = ("Profit", "sum"))
 
print(result)
result = result.assign(profit_margin = (result['Total_profit'] / result['Total_sales'])*100)
    
result
# Out:
#                  Total_sales  Total_profit
# Category
# Furniture        741999.7953    18451.2728
# Office Supplies  719047.0320   122490.8008
# Technology       836154.0330   145454.9481
#                  Total_sales  Total_profit  profit_margin
# Category
# Furniture        741999.7953    18451.2728       2.486695
# Office Supplies  719047.0320   122490.8008      17.035158
# Technology       836154.0330   145454.9481      17.395712

# %%
# Normalize sales by subtracting the mean and dividing by std.

# Use .transform() when you want to return a Series aligned to the original DataFrame (most common in normalization, z-scores, etc.).
# Using transform (vectorized, returns aligned Series)
# store_df['Sales_norm_transform'] = store_df.groupby('Category')['Sales'].transform(lambda x : (x- x.mean())/x.std())
# store_df['Sales_norm_transform']



# Use .apply() when you want to return a reduced object (summary, custom output, maybe different shapes).
# Using apply (returns concatenated pieces, may lose alignment if not careful)
normed = store_df.groupby("Category")["Sales"].apply(
    lambda x: (x - x.mean()) / x.std()
)
store_df["Sales_norm_apply"] = normed.reset_index(level=0, drop=True) ## need to reset index
store_df["Sales_norm_apply"]
# Out:
# 0      -0.174639
# 1       0.759382
# 2      -0.273964
# 3       1.207806
# 4      -0.253691
#           ...
# 9989   -0.645072
# 9990   -0.512491
# 9991   -0.175107
# 9992   -0.234768
# 9993    0.324023
# Name: Sales_norm_apply, Length: 9994, dtype: float64

# %%
pivot = pd.pivot_table(store_df, values="Sales", index="Region", columns="Category", aggfunc="sum", fill_value=0)
print(pivot)
# Out:
# Category    Furniture  Office Supplies  Technology
# Region
# Central   163797.1638       167026.415  170416.312
# East      208291.2040       205516.055  264973.981
# South     117298.6840       125651.313  148771.908
# West      252612.7435       220853.249  251991.832

# %%
## Rolling 30-day moving average sales

# store_df['Order Date'] = pd.to_datetime(store_df['Order Date'])
# store_df = store_df.sort_values("Order Date")
# store_df = store_df.set_index("Order Date")

# store_df["Sales_30d_MA"] = store_df["Sales"].rolling("30D").mean()
# print(store_df[["Sales", "Sales_30d_MA"]].head(20))
store_df["Profit_30d_MA"] = store_df["Profit"].rolling("30D").mean()
print(store_df[["Profit", "Profit_30d_MA"]].head(20))
# Out:
#               Profit  Profit_30d_MA
# Order Date
# 2014-01-03    5.5512       5.551200
# 2014-01-04    4.2717       4.911450
# 2014-01-04  -64.7748     -18.317300
# 2014-01-04   -5.4870     -15.109725
# 2014-01-05    4.8840     -11.110980
# 2014-01-06    1.4796      -9.012550
# 2014-01-06  746.4078      98.904643
# 2014-01-06  274.4910     120.852937
# 2014-01-06    5.2398     108.007033
# 2014-01-06  113.6742     108.573750
# 2014-01-06  204.1092     117.258791
# 2014-01-06    0.3112     107.513158
# 2014-01-06    3.0084      99.474331
# 2014-01-06    9.3312      93.035536
# 2014-01-07  -53.7096      83.252527
# 2014-01-07  -18.2525      76.908462
# 2014-01-09    1.1680      72.453141
# 2014-01-09    9.7500      68.969633
# 2014-01-10   21.2954      66.460463
# 2014-01-10    1.3583      63.205355

# %% [markdown]
# ## IMDB DATASET

# %%
# imdb = pd.read_csv("IMDB Dataset.csv")
# imdb

# ON KAGGLE
